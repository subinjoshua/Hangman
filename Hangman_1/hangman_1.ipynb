# %%
#hangman game
import random
import sys








def rules():
    print(" Rules of the game:\n")
    print(" 1.You have 6 wrong tries before the hangman gets you!\n")
    print(""" 2.If the word given by hangman has recurring letters, all of it will be displayed if you can guess the letter once\n
    """)
##################################################################################################################
def filler():                                              #fills visual_answer with ___
    for i in range(0,len(answer)):
        visual_answer.append("___")
        #print("Filler worked!",visual_answer)
##################################################################################################################        

               

def winning_check():
    winning_count=0
    for i in range(0,len(visual_answer)):
        if visual_answer[i].isalpha():
            winning_count=winning_count+1
        else:
            pass
    #print("winning count is {}".format(winning_count))
    if winning_count==len(answer):
        game_over_win()
    else:
        user_input()  
    
#################################################################################################################                 
def random_finder():
    m_rand=random.sample(answer,2)
    #print("Randomer works!")
    replacer(m_rand)

def replacer(x):
    #fills visual_answer with LETTERS
    for i in x:
        letter_count=-1
        for j in answer:
            if i==j:
                letter_count+=1
                visual_answer[letter_count]=i
            else:
                letter_count+=1
    #print("replacer works")
    visual_clue()


def visual_clue():
    print("This is the word : ",end="  ")                  
    for i in visual_answer:
        print(i,sep="  ", end= " ")
    print("\n")
    winning_check()
##################################################################################################################    
    
    
def user_input():
    global letter_input
    letter_input=""
    letter_input=input("Guess a letter : ")
    letter_check(letter_input)
    letter_input=letter_input.upper()
    answer_against_input_checker(letter_input)
    
##################################################################################################################    
def letter_check(letter_input):                                  #this checks if the inupt is an alphabet
    if letter_input.isalpha():                                   #working
        return True
    else:
        print("This only accepts letters.Try Again!\n")
        user_input()
###################################################################################################################

def answer_against_input_checker(letter_input):
    if letter_input in visual_answer:
        print("Sorry! This letter already exists!\n")
        user_input()
    else:
        if letter_input in answer:
            #if i == letter_input:
            print("Correct Guess!\n")
            replacer(letter_input)
            
        else:
            
            #print("answer_against_input_checker is moving to fail with value being {}".format(letter_input))
            #print(answer)
            failed_tries(letter_input)
                
##################################################################################################################
        
def failed_tries(letter_input):
    global user_try
    user_try+=1
    if user_try ==6:
        print("{} does not exisit in the word! This was your last try :( \n".format(letter_input))
        game_over_loss()
    else:
        print("{} does not exisit in the word! This is your {}/6 tries \n".format(letter_input,user_try))
    user_input()
##################################################################################################################    
def game_over_loss():
    print("Game over!\n")
    print("The word you had to guess is: {}".format(answer))
    play_again()
##################################################################################################################
def game_over_win():
    print("YAY! You have won!\n")
    play_again()
##################################################################################################################
    
def play_again():
    print("Would you like to play again?\n")
    restart=input("Y/N?")
    if restart=="y" or restart=="Y":
        game_refresh()
    else:
        game_stop()
##################################################################################################################

def game_stop():
    print("Hope you have enjoyed playing this game as much as I have enjoyed making this!")
    sys.exit()

##################################################################################################################
def game_start():
    
    print("\t\t Welcome to Subin's Hangman game!\n")
    rules()
    filler()
    random_finder()
    
    
##################################################################################################################
def game_refresh():
    visual_answer.clear()
    user_try=0
    index_count=-1
    game_start()
    
#################################################################################################################
    
    

import random
import sys

global answer
answer="Tribbiani"
answer=answer.upper()
global user_try
user_try=0
index_count=-1
visual_answer=[]    

game_start()
    
    
    
    
    
    

        
#control flow:
#filler|--> random_finder --> replacer --> winning_check-->{game_over_win}
#winning_check-->user_input -->answer_against_input_checker -- >user_input
#answer_against_input_checker -->replacer
# Out:
# 		 Welcome to Subin's Hangman game!
#
# This is the word :   ___ ___ I B B I ___ ___ I
#
# Guess a letter : h
# H does not exisit in the word! This is your 1/6 tries
#
# Guess a letter : c
# C does not exisit in the word! This is your 2/6 tries
#
# Guess a letter : a
# Correct Guess!
#
# This is the word :   ___ ___ I B B I A ___ I
#
# Guess a letter : p
# P does not exisit in the word! This is your 3/6 tries
#
# Guess a letter : f
# F does not exisit in the word! This is your 4/6 tries
#
# Guess a letter : g
# G does not exisit in the word! This is your 5/6 tries
#
# Guess a letter : w
# W does not exisit in the word! This was your last try :(
#
# Game over!
#
# The word you had to guess is: TRIBBIANI
# Would you like to play again?
#
# Y/N?y
# 		 Welcome to Subin's Hangman game!
#
# This is the word :   T ___ I ___ ___ I ___ ___ I
#
# Guess a letter : r
# Correct Guess!
#
# This is the word :   T R I ___ ___ I ___ ___ I
#
# Guess a letter : b
# Correct Guess!
#
# This is the word :   T R I B B I ___ ___ I
#
# Guess a letter : a
# Correct Guess!
#
# This is the word :   T R I B B I A ___ I
#
# Guess a letter : n
# Correct Guess!
#
# This is the word :   T R I B B I A N I
#
# YAY! You have won!
#
# Would you like to play again?
#
# Y/N?n
# Hope you have enjoyed playing this game as much as I have enjoyed making this!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
